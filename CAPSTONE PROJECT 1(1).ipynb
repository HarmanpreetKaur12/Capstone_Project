# %% [markdown]
# # Importing Libraries

# %%
# Importing Libraries
import numpy as np  #array
import pandas as pd #data manipulation and analysis.

#libraries for visualization
import seaborn as sns    #for making statistical graphics. 
import matplotlib.pyplot as plt   #creating static, animated, and interactive visualizations in Python.

#avoid warning
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## ADULT INCOME DATA

# %%
#read csv file
data= pd.read_csv("C:/Users/DhanD/OneDrive/Desktop/Capstone/ADULT INCOME.csv")
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#for showing/listing attribute 
data.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'educational-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'gender',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'income'],
#       dtype='object')

# %%
#fetching information about dataset
data.info
# Out:
# <bound method DataFrame.info of        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
#for Printing top 7 records
data.head(7)
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
# 5   34    Private  198693          10th                6       Never-married
# 6   29          ?  227026       HS-grad                9       Never-married
#
#           occupation   relationship   race  gender  capital-gain  \
# 0  Machine-op-inspct      Own-child  Black    Male             0
# 1    Farming-fishing        Husband  White    Male             0
# 2    Protective-serv        Husband  White    Male             0
# 3  Machine-op-inspct        Husband  Black    Male          7688
# ...

# %%
#size of dataset
data.size
# Out:
# 732630

# %%
#defining number of rows and columns
data.shape
# Out:
# (48842, 15)

# %%
#for unique value of attributes
data['education'].unique()
# Out:
# array(['11th', 'HS-grad', 'Assoc-acdm', 'Some-college', '10th',
#        'Prof-school', '7th-8th', 'Bachelors', 'Masters', 'Doctorate',
#        '5th-6th', 'Assoc-voc', '9th', '12th', '1st-4th', 'Preschool'],
#       dtype=object)

# %%
data['educational-num'].unique()
# Out:
# array([ 7,  9, 12, 10,  6, 15,  4, 13, 14, 16,  3, 11,  5,  8,  2,  1],
#       dtype=int64)

# %%
#Checking unique values for all Categorical columns(workclass,education,MaritalStatus,occupation,
#relationship,race,gender,Country,income )

print("workclass:", data['workclass'].unique())
print("education:", data['education'].unique())
print("MaritalStatus :", data['marital-status'].unique())
print("occupation :", data['occupation'].unique())
print("relationship :", data['relationship'].unique())
print("race :", data['race'].unique())
print("gender :", data['gender'].unique())
print("capital-gain :", data['capital-gain'].unique())
print("capital-loss :", data['capital-loss'].unique())
print("Country :", data['native-country'].unique())
print("income :", data['income'].unique())
# Out:
# workclass: ['Private' 'Local-gov' '?' 'Self-emp-not-inc' 'Federal-gov' 'State-gov'
#  'Self-emp-inc' 'Without-pay' 'Never-worked']
# education: ['11th' 'HS-grad' 'Assoc-acdm' 'Some-college' '10th' 'Prof-school'
#  '7th-8th' 'Bachelors' 'Masters' 'Doctorate' '5th-6th' 'Assoc-voc' '9th'
#  '12th' '1st-4th' 'Preschool']
# MaritalStatus : ['Never-married' 'Married-civ-spouse' 'Widowed' 'Divorced' 'Separated'
#  'Married-spouse-absent' 'Married-AF-spouse']
# occupation : ['Machine-op-inspct' 'Farming-fishing' 'Protective-serv' '?'
#  'Other-service' 'Prof-specialty' 'Craft-repair' 'Adm-clerical'
#  'Exec-managerial' 'Tech-support' 'Sales' 'Priv-house-serv'
#  'Transport-moving' 'Handlers-cleaners' 'Armed-Forces']
# relationship : ['Own-child' 'Husband' 'Not-in-family' 'Unmarried' 'Wife' 'Other-relative']
# race : ['Black' 'White' 'Asian-Pac-Islander' 'Other' 'Amer-Indian-Eskimo']
# gender : ['Male' 'Female']
# ...

# %%
# Counting the occurence of values for workclass
data["workclass"].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
# Counting the occurence of values for marital-status
data["marital-status"].value_counts()
# Out:
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: marital-status, dtype: int64

# %%
# Counting the occurence of values for education
data["education"].value_counts()
# Out:
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: education, dtype: int64

# %%
# Counting the occurence of values for occupation
data["occupation"].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
# Counting the occurence of values for relationship
data["relationship"].value_counts()
# Out:
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64

# %%
# Counting the occurence of values for race
data["race"].value_counts()
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
# Counting the occurence of values for gender
data["gender"].value_counts()
# Out:
# Male      32650
# Female    16192
# Name: gender, dtype: int64

# %%
# Counting the occurence of values for Country
data["native-country"].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Greece                           49
# ...

# %%
# Counting the occurence of values for income
data["income"].value_counts()
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
#defining datatype of all columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # Data Cleaning

# %%
#checking and counting no of null values for each attributes corresponding
print(data.isnull().sum())
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
##checking and counting no of missing values in the form of '?' for each attributes corresponding
a = data.isin(['?']).sum()
a.to_csv("null.csv")

# %%
#draw heat map for missing values
plt.figure(figsize=(15,5))
sns.heatmap(data.isin(['?']))
plt.title('Missing Values')
plt.show()

# %% [markdown]
# ### This heat map shows the missing values.The count of missing values in Workclass,Occupation are reported to be approximately same which are 2799 and 2899 respectively .the count of missing values in Native country is 857.

# %%
#removing missing values
data.drop(data.index[data['workclass'] == '?'],inplace=True)
data.drop(data.index[data['occupation'] == '?'],inplace=True)
data.drop(data.index[data['native-country'] == '?'],inplace=True)

# %%
#checking the count of missing value in the form of '?' 
data.isin(['?']).sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
#show data
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
# counting the duplicate rows in the dataset 
data.duplicated().sum()
# Out:
# 47

# %%
# removing duplicate values from the dataset
data.drop_duplicates(inplace = True)     #inplace = True the data frame has to make changes permanent

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 5       34       Private  198693          10th                6
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# ...

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  45175.000000  4.517500e+04     45175.000000  45175.000000
# mean      38.556170  1.897388e+05        10.119314   1102.576270
# std       13.215349  1.056524e+05         2.551740   7510.249876
# min       17.000000  1.349200e+04         1.000000      0.000000
# 25%       28.000000  1.173925e+05         9.000000      0.000000
# 50%       37.000000  1.783120e+05        10.000000      0.000000
# 75%       47.000000  2.379030e+05        13.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  45175.000000    45175.000000
# mean      88.687593       40.942512
# std      405.156611       12.007730
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
# summarize the class distribution
from collections import Counter
target = data.values[:,-1]
counter = Counter(target)
for k,v in counter.items():
   per = v / len(target) * 100
   print('Class=%s, Count=%d, Percentage=%.3f%%' % (k, v, per))
# Out:
# Class=<=50K, Count=33973, Percentage=75.203%
# Class=>50K, Count=11202, Percentage=24.797%

# %%
# Descriptive Analytics of quantitative variables 
categorical_columns = list(data.select_dtypes(include=['object']).columns)
print('Categorical columns:\n {}'.format(categorical_columns))
# Out:
# Categorical columns:
#  ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country', 'income']

# %%
categorical_columns= data.select_dtypes(include='object')
categorical_columns
# Out:
#           workclass     education      marital-status         occupation  \
# 0           Private          11th       Never-married  Machine-op-inspct
# 1           Private       HS-grad  Married-civ-spouse    Farming-fishing
# 2         Local-gov    Assoc-acdm  Married-civ-spouse    Protective-serv
# 3           Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 5           Private          10th       Never-married      Other-service
# ...             ...           ...                 ...                ...
# 48837       Private    Assoc-acdm  Married-civ-spouse       Tech-support
# 48838       Private       HS-grad  Married-civ-spouse  Machine-op-inspct
# 48839       Private       HS-grad             Widowed       Adm-clerical
# 48840       Private       HS-grad       Never-married       Adm-clerical
# 48841  Self-emp-inc       HS-grad  Married-civ-spouse    Exec-managerial
#
#         relationship   race  gender native-country income
# ...

# %%
numerical_columns = list(data.select_dtypes(include=['int64', 'float64']).columns)
print('Numerical columns:\n {}'.format(numerical_columns))
# Out:
# Numerical columns:
#  ['age', 'fnlwgt', 'educational-num', 'capital-gain', 'capital-loss', 'hours-per-week']

# %%
numerical_columns = data.select_dtypes(exclude='object')
numerical_columns
# Out:
#        age  fnlwgt  educational-num  capital-gain  capital-loss  \
# 0       25  226802                7             0             0
# 1       38   89814                9             0             0
# 2       28  336951               12             0             0
# 3       44  160323               10          7688             0
# 5       34  198693                6             0             0
# ...    ...     ...              ...           ...           ...
# 48837   27  257302               12             0             0
# 48838   40  154374                9             0             0
# 48839   58  151910                9             0             0
# 48840   22  201490                9             0             0
# 48841   52  287927                9         15024             0
#
#        hours-per-week
# 0                  40
# 1                  50
# 2                  40
# 3                  40
# 5                  30
# ...               ...
# 48837              38
# ...

# %%
numerical_columns = data.select_dtypes(include=['int64', 'float64']).columns
# select a subset of the dataframe with the chosen columns
subset = data[numerical_columns]
# create a histogram plot of each numeric variable
subset.hist()
from matplotlib import pyplot
pyplot.show()

# %% [markdown]
# ## These histogram shows that numerical attributes like Age,fnlwgt,educational_num,capital-loss,capital-gain and hour-per-week

# %% [markdown]
# ### Find Total Number of Persons Having Age Between 17 To 48 (Inclusive) Using Between Method

# %%
data[(data['age']>17) & (data['age']<=48)].shape[0]
# Out:
# 34366

# %%
data['age'].between(17, 48).sum()
# Out:
# 34858

# %% [markdown]
# ### How many People Having Bachelors and Masters Degree?

# %%
data[(data['education']=='Bachelors') | (data['education']=='Masters')].shape[0]
# Out:
# 10072

# %% [markdown]
# ## Bivariate Analysis

# %%
#relationship between Income and age
sns.catplot(data=data, x='income', y='age', kind= 'box', aspect=2)
plt.title('Relationship between Income and Age')
plt.show()

# %%
#from sklearn.preprocessing import MinMaxScaler

data.var(axis=0)
data.loc[:, numerical_columns].var()
# Out:
# age                1.746454e+02
# fnlwgt             1.116244e+10
# educational-num    6.511376e+00
# capital-gain       5.640385e+07
# capital-loss       1.641519e+05
# hours-per-week     1.441856e+02
# dtype: float64

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Numerical attributes

# %%
#checking for outliers 
for i in numerical_columns:
 sns.boxplot(data[i])
 plt.show()

# %% [markdown]
# ### This age Boxplot shows the Age attribute is positive skewed and maximum outliers are above the 80 age.
#
# ### This age Boxplot shows the Fnlwgt attribute of Adult income Data.This attribute is positive skewed and outliers lies above Upper Quartiles.
#
# ### This age Boxplot shows the Education-num attribute of Adult income Data.This attribute is negative skewed.outliers lies below Lower Quartiles.
#
# ### This age Boxplot shows the Hours-per-week attribute of Adult income Data.This attribute is normal distribution.outliers lies below Lower Quartiles and above Upper Quartiles.

# %% [markdown]
# ## Categorical attributes

# %%
plt.figure(figsize=(10,7))
grp=data['workclass'].value_counts()
sns.barplot(grp.index,grp.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### This bar chart shows the workclass of Adult income Dataset.In this,Private workclass is reported to be maximum count of workclass and count of Self-emp-inc and Federal-gov are report is same

# %%
plt.figure(figsize=(22,10))
grp=data['education'].value_counts()
sns.barplot(grp.index,grp.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### This bar chart shows the education of Adult income Dataset.In this,HS-Grad Education level  has maximum count of Education level.The count of Education Level is decreasing countinuously

# %%
plt.figure(figsize=(15,7))
grp=data['marital-status'].value_counts()
sns.barplot(grp.index,grp.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### This bar chart shows the maximum count of Marital-status is Married-civ-spouse followed by Never-married. Count of Separted and windowed is report to be same.Negligible count is reported of Married-AF-spouse.

# %%
plt.figure(figsize=(23,7))
grp=data['occupation'].value_counts()
sns.barplot(grp.index,grp.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### This bar plot shows the Occupation of Adult income dataset.Count of Craft-Repair,Prof-Speciality and Executive Manager level occupation is reported to be same which is 6000 followed by Adm-clerical and Sales which is 5800.the count of occupation is decreasing continuously and Armed-Forces has reported to be negligible.

# %%
plt.figure(figsize=(8,5))
sns.countplot(data["relationship"])
plt.show()

# %% [markdown]
# ### This countplot shows the relationship of Adult income data.Maximum count of relationship is Husband which is 18000.The count of Wife and other-relative are found to be approximately same which is 2200 and 2100 respectively.

# %%
plt.figure(figsize= (10,5))
plt.hist(data["race"])
plt.show()

# %% [markdown]
# ### This Histogram shows the race of Adult income data.Maximum number of race is accounted to be White and Minimum are Amer-Indian-ESkimo and other.

# %%
plt.figure(figsize =(30,10))
sns.countplot(data["native-country"])
plt.show()

# %% [markdown]
# ### This countplot shows the native country of Adult Income data.Maximum count of population belongs to United states and others country have less population is reported to be negligible for calculation Adult income data

# %%
#plt.figure(figsize=(10,7))
grp=data['gender'].value_counts()
sns.barplot(grp.index,grp.values)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### This barplot shows the gender .The count of Female is accounted to be exactly half of Count of Male  which is 15000.

# %% [markdown]
# ## Co-relation between Attributes

# %%
corr=data.corr()
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# ### This Heat Map shows correlation of attributes.

# %%
#removing outliers(Z-score treatment)
# In this technique, we cap our outliers data and make the limit i.e, above a particular value or less than that value, 
#all the values will be considered as outliers, and the number of outliers in the dataset gives that capping number.

#For Normal distributions: Use empirical relations of Normal distribution.
#The data points which fall below mean-3*(sigma) or above mean+3*(sigma) are outliers.
#where mean and sigma are the average value and standard deviation of a particular column.

#Finding the Boundary Values

print("Highest allowed of age ",data['age'].mean() + 3*data['age'].std())
print("Lowest allowed of age",data['age'].mean() - 3*data['age'].std())

print("Highest allowed of fnlwgt",data['fnlwgt'].mean() + 3*data['fnlwgt'].std())
print("Lowest allowed of fnlwgt",data['fnlwgt'].mean() - 3*data['fnlwgt'].std())

print("Highest allowed of educational-num",data['educational-num'].mean() + 3*data['educational-num'].std())
print("Lowest allowed of educational-num",data['educational-num'].mean() - 3*data['educational-num'].std())

#print("Highest allowed",data['gender'].mean() + 3*data['gender'].std())
#print("Lowest allowed",data['gender'].mean() - 3*data['gender'].std())

print("Highest allowed of capital-gain",data['capital-gain'].mean() + 3*data['capital-gain'].std())
print("Lowest allowed of capital-gain",data['capital-gain'].mean() - 3*data['capital-gain'].std())

print("Highest allowed of capital-loss",data['capital-loss'].mean() + 3*data['capital-loss'].std())
print("Lowest allowed of capital-loss",data['capital-loss'].mean() - 3*data['capital-loss'].std())

print("Highest allowed of hours-per-week",data['hours-per-week'].mean() + 3*data['hours-per-week'].std())
print("Lowest allowed of hours-per-week",data['hours-per-week'].mean() - 3*data['hours-per-week'].std())

#print("Highest allowed of income",data['income'].mean() + 3*data['income'].std())
#print("Lowest allowed of income",data['income'].mean() - 3*data['income'].std())
# Out:
# Highest allowed of age  78.20221668366378
# Lowest allowed of age -1.0898757871502198
# Highest allowed of fnlwgt 506696.10799399647
# Lowest allowed of fnlwgt -127218.51109305563
# Highest allowed of educational-num 17.774533166618433
# Lowest allowed of educational-num 2.464094392872436
# Highest allowed of capital-gain 23633.325898911702
# Lowest allowed of capital-gain -21428.17335878995
# Highest allowed of capital-loss 1304.157426703193
# Lowest allowed of capital-loss -1126.7822413130436
# Highest allowed of hours-per-week 76.96570335051013
# Lowest allowed of hours-per-week 4.919321552644277

# %%
 #  Finding the Outliers
 #(Bitwise  Or (!) The result in each position is 0 if both bits are 0, while otherwise the result is 1.)

 data[(data['age'] > 79.28838133208404) |(data['age'] < -1.583990561831719)] 
 data[(data['fnlwgt'] > 506809.5920015615) | (data['fnlwgt'] < -127177.79834286292)]
 data[(data['educational-num'] > 17.788044955224105) | (data['educational-num'] <2.451870383421312)]
 data[(data['capital-gain'] > 8195.875932468383) | (data['capital-gain'] < -7017.486386452513)]
 data[(data['capital-loss'] > 1300.3210418401006) | (data['capital-loss'] < -1124.2070810167277)]
 data[(data['hours-per-week'] > 75.96451214978259) | (data['hours-per-week'] < 5.034575732884335)]
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 25      45  Self-emp-not-inc  432824       HS-grad                9
# 309     51  Self-emp-not-inc  136708       HS-grad                9
# 338     36      Self-emp-inc   48063       HS-grad                9
# 354     32           Private  224462       HS-grad                9
# 357     50  Self-emp-not-inc  165001   Prof-school               15
# ...    ...               ...     ...           ...              ...
# 48645   45           Private  190482     Assoc-voc               11
# 48672   55           Private  199763       HS-grad                9
# 48683   42           Private  288154  Some-college               10
# 48740   85           Private   98611     Bachelors               13
# 48757   35           Private   30673          12th                8
#
#            marital-status        occupation   relationship  \
# 25     Married-civ-spouse      Craft-repair        Husband
# ...

# %%
#Trimming of Outliers
#(Bitwise And (&) if both bits in the compared position are 1, the bit in the resulting binary representation is 1 
 #(1 × 1 = 1); otherwise, the result is 0)
    
data = data[(data['age'] < 79.28838133208404) & (data['age'] > -1.583990561831719)]
data = data[(data['fnlwgt'] < 506809.5920015615) & (data['fnlwgt'] > -127177.79834286292)]
data = data[(data['educational-num'] < 17.788044955224105) & (data['educational-num'] >2.451870383421312)]
data = data[(data['capital-gain'] <8195.875932468383) & (data['capital-gain'] > -7017.486386452513)]
data = data[(data['capital-loss'] < 1300.3210418401006) & (data['capital-loss'] > -1124.2070810167277)]
data = data[(data['hours-per-week'] < 75.96451214978259) & (data['hours-per-week'] > 5.034575732884335)]

# %%
data
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 0       25    Private  226802          11th                7
# 1       38    Private   89814       HS-grad                9
# 2       28  Local-gov  336951    Assoc-acdm               12
# 3       44    Private  160323  Some-college               10
# 5       34    Private  198693          10th                6
# ...    ...        ...     ...           ...              ...
# 48836   22    Private  310152  Some-college               10
# 48837   27    Private  257302    Assoc-acdm               12
# 48838   40    Private  154374       HS-grad                9
# 48839   58    Private  151910       HS-grad                9
# 48840   22    Private  201490       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 0           Never-married  Machine-op-inspct      Own-child  Black    Male
# 1      Married-civ-spouse    Farming-fishing        Husband  White    Male
# ...

# %%
#Capping on Outliers

upper_limit = data['age'].mean() + 3*data['age'].std()
lower_limit = data['age'].mean() - 3*data['age'].std()
upper_limit = data['fnlwgt'].mean() + 3*data['fnlwgt'].std()
lower_limit = data['fnlwgt'].mean() - 3*data['fnlwgt'].std()
upper_limit = data['educational-num'].mean() + 3*data['educational-num'].std()
lower_limit = data['educational-num'].mean() - 3*data['educational-num'].std()
upper_limit = data['capital-gain'].mean() + 3*data['capital-gain'].std()
lower_limit = data['capital-gain'].mean() - 3*data['capital-gain'].std()
upper_limit = data['capital-loss'].mean() + 3*data['capital-loss'].std()
lower_limit = data['capital-loss'].mean() - 3*data['capital-loss'].std()
upper_limit = data['hours-per-week'].mean() + 3*data['hours-per-week'].std()
lower_limit = data['hours-per-week'].mean() - 3*data['hours-per-week'].std()

# %%
#Capping on Outliers

data['age'] = np.where(
    data['age']>upper_limit,
    upper_limit,
    np.where(
        data['age']<lower_limit,
        lower_limit,
        data['age']
    )
)

data['fnlwgt'] = np.where(
    data['fnlwgt']>upper_limit,
    upper_limit,
    np.where(
        data['fnlwgt']<lower_limit,
        lower_limit,
        data['fnlwgt']
    )
)

data['educational-num'] = np.where(
    data['educational-num']>upper_limit,
    upper_limit,
    np.where(
        data['educational-num']<lower_limit,
        lower_limit,
        data['educational-num']
    )
)

data['capital-gain'] = np.where(
    data['capital-gain']>upper_limit,
    upper_limit,
    np.where(
        data['capital-gain']<lower_limit,
        lower_limit,
        data['capital-gain']
    )
)

data['capital-loss'] = np.where(
    data['capital-loss']>upper_limit,
    upper_limit,
    np.where(
        data['capital-loss']<lower_limit,
        lower_limit,
        data['capital-loss']
    )
)

data['hours-per-week'] = np.where(
    data['hours-per-week']>upper_limit,
    upper_limit,
    np.where(
        data['hours-per-week']<lower_limit,
        lower_limit,
        data['hours-per-week']
    )
)

# %%
#after removing outliers
for i in numerical_columns:
 sns.boxplot(data[i])
 plt.show()

# %% [markdown]
# ### This Boxplot shows removing the outliers.

# %%
from sklearn.metrics import classification_report
categorical_columns = data.select_dtypes(include='object')
numerical_columns = data.select_dtypes(exclude='object')
categorical_columns.describe(include='all')
# Out:
#        workclass education      marital-status    occupation relationship  \
# count      40468     40468               40468         40468        40468
# unique         7        14                   7            14            6
# top      Private   HS-grad  Married-civ-spouse  Craft-repair      Husband
# freq       30151     13672               18222          5516        16121
#
#          race gender native-country income
# count   40468  40468          40468  40468
# unique      5      2             40      2
# top     White   Male  United-States  <=50K
# freq    34766  26887          37092  31803

# %%
from sklearn.metrics import classification_report
categorical_columns = data.select_dtypes(include='object')
numerical_columns = data.select_dtypes(exclude='object')
numerical_columns.describe(include='all')
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  40468.000000  4.046800e+04     40468.000000  40468.000000
# mean      37.948238  7.233695e+01        10.363466     12.210474
# std       12.878122  8.469774e-12         1.919633     15.445243
# min       17.000000  7.233695e+01         8.243011      8.243011
# 25%       28.000000  7.233695e+01         9.000000      8.243011
# 50%       37.000000  7.233695e+01        10.000000      8.243011
# 75%       47.000000  7.233695e+01        12.000000      8.243011
# max       72.336954  7.233695e+01        16.000000     72.336954
#
#        capital-loss  hours-per-week
# count  40468.000000    40468.000000
# mean       8.342791       40.288839
# std        2.526960       10.647986
# min        8.243011        8.243011
# 25%        8.243011       40.000000
# 50%        8.243011       40.000000
# 75%        8.243011       45.000000
# max       72.336954       72.336954

# %% [markdown]
# ### These Boxplots shows that the relationship between income(less than 50k and more than 50k) and age. These boxplot show that more age i.e elder people are earning more income than younger.

# %%
counts = data.nunique()
counts
# Out:
# age                57
# workclass           7
# fnlwgt              1
# education          14
# educational-num     9
# marital-status      7
# occupation         14
# relationship        6
# race                5
# gender              2
# capital-gain        2
# capital-loss        2
# hours-per-week     65
# native-country     40
# income              2
# dtype: int64

# %%
#categorial_columns1 = ['workclass','marital-status','relationship','race','gender','native-country']

# %%
#encoding categorical attributes into numerical by creating Dummy
#categorical_columns = pd.get_dummies(categorical_columns)
#categorical_columns.head()

# %%
#categorical_columns1 = ['workclass','marital-status','relationship','race','gender','native-country']

# %%
#encoding categorical attributes into numerical by creating Dummy
#categorical_columns1 = pd.get_dummies(categorical_columns1)
#categorical_columns1.head()

# %% [markdown]
# # Encoding
#  encoding is done by feature scaling

# %%
# {0: ' Adm-clerical',1: ' Exec-managerial',2: ' Handlers-cleaners',3: ' Prof-specialty',4: ' Other-service',5: ' Sales', 6: ' Craft-repair',7: ' Transport-moving',8: ' Farming-fishing',9: ' Machine-op-inspct', 10: ' Tech-support', 11: ' ?',12: ' Protective-serv',13: ' Armed-Forces', 14: ' Priv-house-serv'}
#data['occupation'] = np.where(data['occupation'])
#label_enco_occu = {value: key for key, value in enumerate(data['occupation'].unique())}
## Replacing ? value with 'Missing'
#data['occupation'] = data['occupation'].map(label_enco_occu)
# {0: ' Not-in-family',1: ' Husband'2: ' Wife',3: ' Own-child',4: ' Unmarried',5: ' Other-relative
label_enco_relation = {value: key for key, value in enumerate(data['occupation'].unique())}
data['occupation'] = data['occupation'].map(label_enco_relation)
data
# Out:
#         age  workclass     fnlwgt     education  educational-num  \
# 0      25.0    Private  72.336954          11th         8.243011
# 1      38.0    Private  72.336954       HS-grad         9.000000
# 2      28.0  Local-gov  72.336954    Assoc-acdm        12.000000
# 3      44.0    Private  72.336954  Some-college        10.000000
# 5      34.0    Private  72.336954          10th         8.243011
# ...     ...        ...        ...           ...              ...
# 48836  22.0    Private  72.336954  Some-college        10.000000
# 48837  27.0    Private  72.336954    Assoc-acdm        12.000000
# 48838  40.0    Private  72.336954       HS-grad         9.000000
# 48839  58.0    Private  72.336954       HS-grad         9.000000
# 48840  22.0    Private  72.336954       HS-grad         9.000000
#
#            marital-status  occupation   relationship   race  gender  \
# 0           Never-married           0      Own-child  Black    Male
# ...

# %%
label_enco_edu = {value: key for key, value in enumerate(data['education'].unique())}
data['education'] = data['education'].map(label_enco_edu)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  \
# 0      25.0    Private  72.336954          0         8.243011
# 1      38.0    Private  72.336954          1         9.000000
# 2      28.0  Local-gov  72.336954          2        12.000000
# 3      44.0    Private  72.336954          3        10.000000
# 5      34.0    Private  72.336954          4         8.243011
# ...     ...        ...        ...        ...              ...
# 48836  22.0    Private  72.336954          3        10.000000
# 48837  27.0    Private  72.336954          2        12.000000
# 48838  40.0    Private  72.336954          1         9.000000
# 48839  58.0    Private  72.336954          1         9.000000
# 48840  22.0    Private  72.336954          1         9.000000
#
#            marital-status  occupation   relationship   race  gender  \
# 0           Never-married           0      Own-child  Black    Male
# 1      Married-civ-spouse           1        Husband  White    Male
# ...

# %%
label_enco_edu = {value: key for key, value in enumerate(data['native-country'].unique())}
data['native-country'] = data['native-country'].map(label_enco_edu)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  \
# 0      25.0    Private  72.336954          0         8.243011
# 1      38.0    Private  72.336954          1         9.000000
# 2      28.0  Local-gov  72.336954          2        12.000000
# 3      44.0    Private  72.336954          3        10.000000
# 5      34.0    Private  72.336954          4         8.243011
# ...     ...        ...        ...        ...              ...
# 48836  22.0    Private  72.336954          3        10.000000
# 48837  27.0    Private  72.336954          2        12.000000
# 48838  40.0    Private  72.336954          1         9.000000
# 48839  58.0    Private  72.336954          1         9.000000
# 48840  22.0    Private  72.336954          1         9.000000
#
#            marital-status  occupation   relationship   race  gender  \
# 0           Never-married           0      Own-child  Black    Male
# 1      Married-civ-spouse           1        Husband  White    Male
# ...

# %%
# (0: 'White',1: 'Black',2: 'Asian-Pac-Islander',3:'Amer-Indian-Eskimo',4:'Other')
label_enco_race = {value: key for key, value in enumerate(data['race'].unique())}
data['race'] = data['race'].map(label_enco_race)

# %%
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  \
# 0      25.0    Private  72.336954          0         8.243011
# 1      38.0    Private  72.336954          1         9.000000
# 2      28.0  Local-gov  72.336954          2        12.000000
# 3      44.0    Private  72.336954          3        10.000000
# 5      34.0    Private  72.336954          4         8.243011
# ...     ...        ...        ...        ...              ...
# 48836  22.0    Private  72.336954          3        10.000000
# 48837  27.0    Private  72.336954          2        12.000000
# 48838  40.0    Private  72.336954          1         9.000000
# 48839  58.0    Private  72.336954          1         9.000000
# 48840  22.0    Private  72.336954          1         9.000000
#
#            marital-status  occupation   relationship  race  gender  \
# 0           Never-married           0      Own-child     0    Male
# 1      Married-civ-spouse           1        Husband     1    Male
# ...

# %%
# {0: ' Not-in-family',1: ' Husband'2: ' Wife',3: ' Own-child',4: ' Unmarried',5: ' Other-relative
label_enco_relation = {value: key for key, value in enumerate(data['relationship'].unique())}
data['relationship'] = data['relationship'].map(label_enco_relation)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  \
# 0      25.0    Private  72.336954          0         8.243011
# 1      38.0    Private  72.336954          1         9.000000
# 2      28.0  Local-gov  72.336954          2        12.000000
# 3      44.0    Private  72.336954          3        10.000000
# 5      34.0    Private  72.336954          4         8.243011
# ...     ...        ...        ...        ...              ...
# 48836  22.0    Private  72.336954          3        10.000000
# 48837  27.0    Private  72.336954          2        12.000000
# 48838  40.0    Private  72.336954          1         9.000000
# 48839  58.0    Private  72.336954          1         9.000000
# 48840  22.0    Private  72.336954          1         9.000000
#
#            marital-status  occupation  relationship  race  gender  \
# 0           Never-married           0             0     0    Male
# 1      Married-civ-spouse           1             1     1    Male
# ...

# %%
# {0: ' Adm-clerical',1: ' Exec-managerial',2: ' Handlers-cleaners',3: ' Prof-specialty',4: ' Other-service',5: ' Sales', 6: ' Craft-repair',7: ' Transport-moving',8: ' Farming-fishing',9: ' Machine-op-inspct', 10: ' Tech-support', 11: ' ?',12: ' Protective-serv',13: ' Armed-Forces', 14: ' Priv-house-serv'}
#data['occupation'] = np.where(data['occupation'])
#label_enco_occu = {value: key for key, value in enumerate(data['occupation'].unique())}
## Replacing ? value with 'Missing'
#data['occupation'] = data['occupation'].map(label_enco_occu)
# {0: ' Not-in-family',1: ' Husband'2: ' Wife',3: ' Own-child',4: ' Unmarried',5: ' Other-relative
label_enco_relation = {value: key for key, value in enumerate(data['occupation'].unique())}
data['occupation'] = data['occupation'].map(label_enco_relation)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  \
# 0      25.0    Private  72.336954          0         8.243011
# 1      38.0    Private  72.336954          1         9.000000
# 2      28.0  Local-gov  72.336954          2        12.000000
# 3      44.0    Private  72.336954          3        10.000000
# 5      34.0    Private  72.336954          4         8.243011
# ...     ...        ...        ...        ...              ...
# 48836  22.0    Private  72.336954          3        10.000000
# 48837  27.0    Private  72.336954          2        12.000000
# 48838  40.0    Private  72.336954          1         9.000000
# 48839  58.0    Private  72.336954          1         9.000000
# 48840  22.0    Private  72.336954          1         9.000000
#
#            marital-status  occupation  relationship  race  gender  \
# 0           Never-married           0             0     0    Male
# 1      Married-civ-spouse           1             1     1    Male
# ...

# %%
# {0: ' Never-married',1: ' Married-civ-spouse',2: ' Divorced',3: ' Married-spouse-absent',4: ' Separated',5: ' Married-AF-spouse',6: ' Widowed'}
label_enco_marital_status = {value: key for key, value in enumerate(data['marital-status'].unique())}
data['marital-status'] = data['marital-status'].map(label_enco_marital_status)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0      25.0    Private  72.336954          0         8.243011               0
# 1      38.0    Private  72.336954          1         9.000000               1
# 2      28.0  Local-gov  72.336954          2        12.000000               1
# 3      44.0    Private  72.336954          3        10.000000               1
# 5      34.0    Private  72.336954          4         8.243011               0
# ...     ...        ...        ...        ...              ...             ...
# 48836  22.0    Private  72.336954          3        10.000000               0
# 48837  27.0    Private  72.336954          2        12.000000               1
# 48838  40.0    Private  72.336954          1         9.000000               1
# 48839  58.0    Private  72.336954          1         9.000000               2
# 48840  22.0    Private  72.336954          1         9.000000               0
#
# ...

# %%
label_enco_edu = {value: key for key, value in enumerate(data['education'].unique())}
data['education'] = data['education'].map(label_enco_edu)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0      25.0    Private  72.336954          0         8.243011               0
# 1      38.0    Private  72.336954          1         9.000000               1
# 2      28.0  Local-gov  72.336954          2        12.000000               1
# 3      44.0    Private  72.336954          3        10.000000               1
# 5      34.0    Private  72.336954          4         8.243011               0
# ...     ...        ...        ...        ...              ...             ...
# 48836  22.0    Private  72.336954          3        10.000000               0
# 48837  27.0    Private  72.336954          2        12.000000               1
# 48838  40.0    Private  72.336954          1         9.000000               1
# 48839  58.0    Private  72.336954          1         9.000000               2
# 48840  22.0    Private  72.336954          1         9.000000               0
#
# ...

# %%
    
# {0: ' State-gov'1: ' Self-emp-not-inc',2: ' Private',3: ' Federal-gov',4: ' Local-gov',5: ' ?',6: ' Self-emp-inc',7: ' Without-pay',8: ' Never-worked'}
label_enco_edu = {value: key for key, value in enumerate(data['workclass'].unique())}
data['workclass'] = data['workclass'].map(label_enco_edu)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0      25.0          0  72.336954          0         8.243011               0
# 1      38.0          0  72.336954          1         9.000000               1
# 2      28.0          1  72.336954          2        12.000000               1
# 3      44.0          0  72.336954          3        10.000000               1
# 5      34.0          0  72.336954          4         8.243011               0
# ...     ...        ...        ...        ...              ...             ...
# 48836  22.0          0  72.336954          3        10.000000               0
# 48837  27.0          0  72.336954          2        12.000000               1
# 48838  40.0          0  72.336954          1         9.000000               1
# 48839  58.0          0  72.336954          1         9.000000               2
# 48840  22.0          0  72.336954          1         9.000000               0
#
# ...

# %%
label_enco_edu = {value: key for key, value in enumerate(data['native-country'].unique())}
data['native-country'] = data['native-country'].map(label_enco_edu)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0      25.0          0  72.336954          0         8.243011               0
# 1      38.0          0  72.336954          1         9.000000               1
# 2      28.0          1  72.336954          2        12.000000               1
# 3      44.0          0  72.336954          3        10.000000               1
# 5      34.0          0  72.336954          4         8.243011               0
# ...     ...        ...        ...        ...              ...             ...
# 48836  22.0          0  72.336954          3        10.000000               0
# 48837  27.0          0  72.336954          2        12.000000               1
# 48838  40.0          0  72.336954          1         9.000000               1
# 48839  58.0          0  72.336954          1         9.000000               2
# 48840  22.0          0  72.336954          1         9.000000               0
#
# ...

# %%
#changing class from gender to 1 and 0
data['gender'] = data['gender'].astype(str)
data['gender'] = data['gender'].replace('Male', 1)
data['gender'] = data['gender'].replace('Female', 0)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0      25.0          0  72.336954          0         8.243011               0
# 1      38.0          0  72.336954          1         9.000000               1
# 2      28.0          1  72.336954          2        12.000000               1
# 3      44.0          0  72.336954          3        10.000000               1
# 5      34.0          0  72.336954          4         8.243011               0
# ...     ...        ...        ...        ...              ...             ...
# 48836  22.0          0  72.336954          3        10.000000               0
# 48837  27.0          0  72.336954          2        12.000000               1
# 48838  40.0          0  72.336954          1         9.000000               1
# 48839  58.0          0  72.336954          1         9.000000               2
# 48840  22.0          0  72.336954          1         9.000000               0
#
# ...

# %%
#changing class from >50K and <=50K to 1 and 0
data['income'] = data['income'].astype(str)
data['income'] = data['income'].replace('>50K', 1)
data['income'] = data['income'].replace('<=50K', 0)
data
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0      25.0          0  72.336954          0         8.243011               0
# 1      38.0          0  72.336954          1         9.000000               1
# 2      28.0          1  72.336954          2        12.000000               1
# 3      44.0          0  72.336954          3        10.000000               1
# 5      34.0          0  72.336954          4         8.243011               0
# ...     ...        ...        ...        ...              ...             ...
# 48836  22.0          0  72.336954          3        10.000000               0
# 48837  27.0          0  72.336954          2        12.000000               1
# 48838  40.0          0  72.336954          1         9.000000               1
# 48839  58.0          0  72.336954          1         9.000000               2
# 48840  22.0          0  72.336954          1         9.000000               0
#
# ...

# %% [markdown]
# # Normalization
#  Normalizing our attributes using min max scaler
#  y = (y - min_value) / (max_value - min_value)

# %%
##from sklearn.preprocessing import MinMaxScaler
#scaler = MinMaxScaler()
#scaled_features = pd.DataFrame(scaler.fit_transform(income_new_data), columns=income_new_data.columns)
#scaled_features
#numerical =['age','fnlwgt','capital-gain','capital-loss','hours-per-week']
#feature_log_minmax_transform = pd.DataFrame(data= feature_log_transformed)
#feature_log_minmax_transform[numerical] = scaler.fit_transform(feature_log_transformed[numerical])
#display(feature_log_minmax_transform.head(n=5))

# %%
from sklearn import preprocessing 
import pandas as pd
from sklearn.preprocessing  import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
scaled_data = pd.DataFrame(scaler.fit_transform(data), columns= data.columns)

# %%
scaled_data.head(3)
# Out:
#         age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0  0.144569   0.000000     0.0   0.000000         0.000000        0.000000
# 1  0.379493   0.000000     0.0   0.076923         0.097588        0.166667
# 2  0.198782   0.166667     0.0   0.153846         0.484336        0.166667
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0    0.000000           0.0  0.00     1.0           0.0           0.0
# 1    0.076923           0.2  0.25     1.0           0.0           0.0
# 2    0.153846           0.2  0.25     1.0           0.0           0.0
#
#    hours-per-week  native-country  income
# 0        0.495476             0.0     0.0
# 1        0.651497             0.0     0.0
# 2        0.495476             0.0     1.0

# %%
x = data.iloc[:,:-1] # independent
x
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0      25.0          0  72.336954          0         8.243011               0
# 1      38.0          0  72.336954          1         9.000000               1
# 2      28.0          1  72.336954          2        12.000000               1
# 3      44.0          0  72.336954          3        10.000000               1
# 5      34.0          0  72.336954          4         8.243011               0
# ...     ...        ...        ...        ...              ...             ...
# 48836  22.0          0  72.336954          3        10.000000               0
# 48837  27.0          0  72.336954          2        12.000000               1
# 48838  40.0          0  72.336954          1         9.000000               1
# 48839  58.0          0  72.336954          1         9.000000               2
# 48840  22.0          0  72.336954          1         9.000000               0
#
# ...

# %%
y = data.iloc[:,-1] # target
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 5        0
#         ..
# 48836    0
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# Name: income, Length: 40468, dtype: int64

# %%
#y = data

# %% [markdown]
# # Training and Testing Data

# %%
from sklearn.model_selection import train_test_split

# %%
train_input,test_input, train_output,test_output = train_test_split(x,y, test_size = 0.3, random_state=6)

# %%
train_input
# Out:
#         age  workclass     fnlwgt  education  educational-num  marital-status  \
# 46452  45.0          0  72.336954          1              9.0               4
# 4169   26.0          0  72.336954          7             13.0               0
# 32841  24.0          0  72.336954          1              9.0               0
# 28989  28.0          0  72.336954          3             10.0               0
# 20023  30.0          0  72.336954          3             10.0               4
# ...     ...        ...        ...        ...              ...             ...
# 26333  61.0          0  72.336954          1              9.0               2
# 30665  62.0          2  72.336954          7             13.0               1
# 38693  51.0          0  72.336954          1              9.0               1
# 5717   33.0          0  72.336954          8             14.0               1
# 38122  36.0          2  72.336954          1              9.0               4
#
# ...

# %%
train_input.shape
# Out:
# (28327, 14)

# %%
test_input.shape
# Out:
# (12141, 14)

# %%
test_output.shape
# Out:
# (12141,)

# %%
train_output.shape
# Out:
# (28327,)

# %% [markdown]
# # IMBALANCE LEARN IS USED FOR BALANCING

# %%
pip install -U imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
print("Before SMOTE")
train_output.value_counts()
# Out:
# Before SMOTE
# 0    22241
# 1     6086
# Name: income, dtype: int64

# %%
#Synthetic Minority Over-sampling Technique
#SMOTE is a machine learning technique that solves problems that occur when using an imbalanced data set.
#Its goal is to achieve a more balanced distribution of classes by replicating minority class  at random.¶
#!pip install imblearn 
from imblearn.over_sampling import SMOTE
SMOTE = SMOTE(sampling_strategy='minority', random_state=10)

# %%
train_input_SMOTE, train_output_SMOTE= SMOTE.fit_resample(train_input, train_output)
train_input_SMOTE.head(3)
# Out:
#     age  workclass     fnlwgt  education  educational-num  marital-status  \
# 0  45.0          0  72.336954          1              9.0               4
# 1  26.0          0  72.336954          7             13.0               0
# 2  24.0          0  72.336954          1              9.0               0
#
#    occupation  relationship  race  gender  capital-gain  capital-loss  \
# 0           3             2     1       0      8.243011      8.243011
# 1           9             0     1       1      8.243011      8.243011
# 2           3             0     0       0      8.243011      8.243011
#
#    hours-per-week  native-country
# 0            40.0               0
# 1            45.0               0
# 2            40.0               0

# %%
print("after SMOTE:")
train_output_SMOTE.value_counts()
# Out:
# after SMOTE:
# 0    22241
# 1    22241
# Name: income, dtype: int64

# %%
train_input_SMOTE.duplicated().sum()
# Out:
# 6642

# %% [markdown]
# # Modelling With CLASSIFICATION Algorithms

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn import metrics

# %% [markdown]
# ### Logistic regression is a statistical analysis method to predict a binary outcome, such as yes or no, based on prior observations of a data set.
# ##### A logistic regression model predicts a dependent data variable by analyzing the relationship between one or more existing independent variables.

# %%
from sklearn.linear_model import LogisticRegression

# instantiate the model
model = LogisticRegression()

# fit the model
model.fit(train_input_SMOTE, train_output_SMOTE)
predict_logistic=model.predict(test_input)
cf_matrix_logistic = confusion_matrix(test_output,predict_logistic) #confusion matrix to define the performance of a classification algorithm
logistic_acc = accuracy_score(test_output,predict_logistic)*100
print("accuracy of Logistic Regression :", round(logistic_acc,2),"%")
# Out:
# accuracy of Logistic Regression : 73.2 %

# %%
# Plot confusion matrix for Logistic Regression
confusion_matrix_lg = confusion_matrix(test_output,predict_logistic.round())
print("Confusion Matrix - Logistic Regression")
print(confusion_matrix_lg)
# Out:
# Confusion Matrix - Logistic Regression
# [[6987 2575]
#  [ 679 1900]]

# %% [markdown]
# ##### A confusion matrix is a performance measurement tool, often used for machine learning classification tasks where the output of the model could be 2 or more classes (i.e. binary classification and multiclass classification). The confusion matrix is especially useful when measuring recall(how valid the results are), precision(how complete the results are), accuracy of a classification model

# %%
#Display the visualization of the Confusion Matrix.
import seaborn as sns

ax = sns.heatmap(confusion_matrix_lg/np.sum(confusion_matrix_lg), annot=True, 
            fmt='.2%', cmap='Blues')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

plt.show()

# %% [markdown]
# ###### This confusion matrix by Logistic Model shows that the proportion of correctly predicted no-event values(TN), incorrectly predicted event values(FP), incorrectly predicted no-event values (FN), correctly predicted event values(TP Values) are 57.55%,21.21%,5.59% and 15.65% respectively. Total Negative is 63.14% and Total Positive is 36.86%.

# %%
from sklearn.metrics import classification_report
print(classification_report(test_output, predict_logistic))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.73      0.81      9562
#            1       0.42      0.74      0.54      2579
#
#     accuracy                           0.73     12141
#    macro avg       0.67      0.73      0.67     12141
# weighted avg       0.81      0.73      0.75     12141

# %% [markdown]
# ### The k-nearest neighbors (KNN) algorithm is a simple, easy-to-implement supervised machine learning algorithm that can be used to solve both classification and regression problems.

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(train_input_SMOTE, train_output_SMOTE)
pred_knn=knn.predict(test_input)
knn_acc = accuracy_score(test_output,pred_knn)*100
print("accuracy of KNN :", round(knn_acc,2),"%")
# Out:
# accuracy of KNN : 74.52 %

# %%
#Plot confusion matrix for K Nearest Neighbor
confusion_matrix_knn = confusion_matrix(test_output,pred_knn.round())
print("Confusion Matrix - K Nearest Neighbor")
print(confusion_matrix_knn)
# Out:
# Confusion Matrix - K Nearest Neighbor
# [[7192 2370]
#  [ 724 1855]]

# %%
#Display the visualization of the Confusion Matrix.
import seaborn as sns

ax = sns.heatmap(confusion_matrix_knn/np.sum(confusion_matrix_knn), annot=True, 
            fmt='.2%', cmap='PiYG')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

plt.show()

# %% [markdown]
# ###### This confusion matrix for KNN model shows that the proportion of correctly predicted no-event values(TN), incorrectly predicted event values(FP), incorrectly predicted no-event values (FN), correctly predicted event values(TP Values) are 59.24,19.52,5.96 and 15.28 respectively.  .

# %%
from sklearn.metrics import classification_report
print(classification_report(test_output, pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.75      0.82      9562
#            1       0.44      0.72      0.55      2579
#
#     accuracy                           0.75     12141
#    macro avg       0.67      0.74      0.68     12141
# weighted avg       0.81      0.75      0.76     12141

# %% [markdown]
# ### Random forest is a Supervised Machine Learning Algorithm that is used widely in Classification and Regression problems.
# ##### Algorithm is that it can handle the data set containing continuous variables as in the case of regression and categorical variables as in the case of classification. It performs better results for classification problems.

# %%
#Random forests is great with high dimensional data since we are working with subsets of data.
#It is faster to train than decision trees because we are working only on a subset of features in 
#this model, so we can easily work with hundreds of features.

from sklearn.ensemble import RandomForestClassifier 
model=RandomForestClassifier(n_estimators=20)
RFC=model.fit(train_input_SMOTE,train_output_SMOTE)
pred_RFC=RFC.predict(test_input)
RFC_acc = accuracy_score(test_output,pred_RFC)*100
print("accuracy of RFC :", round(RFC_acc,2),"%")
# Out:
# accuracy of RFC : 81.81 %

# %%
#Plot confusion matrix for Random Forests

confusion_matrix_rf = confusion_matrix(test_output, pred_RFC.round())
print("Confusion Matrix - Random Forest")
print(confusion_matrix_rf)
# Out:
# Confusion Matrix - Random Forest
# [[8377 1185]
#  [1024 1555]]

# %%
#Display the visualization of the Confusion Matrix.
import seaborn as sns

ax = sns.heatmap(confusion_matrix_rf/np.sum(confusion_matrix_rf), annot=True, 
            fmt='.2%', cmap='Oranges_r')

ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

plt.show()

# %% [markdown]
# ###### This confusion matrix by Random Forest shows that correctly predicted no-event values(TN), incorrectly predicted event values(FP), incorrectly predicted no-event values (FN), correctly predicted event values(TP Values) are 68.88%,9.88%,8.55% and 12.69% respectively

# %%
from sklearn.metrics import classification_report
print(classification_report(test_output, pred_RFC))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.88      0.88      9562
#            1       0.57      0.60      0.58      2579
#
#     accuracy                           0.82     12141
#    macro avg       0.73      0.74      0.73     12141
# weighted avg       0.82      0.82      0.82     12141

# %% [markdown]
# ### Gaussian Naive Bayes is a probabilistic classification algorithm based on applying Bayes' theorem with strong independence assumptions.This model is used when we assume all the continuous variables associated with each feature to be distributed according to Gaussian Distribution.

# %%
GNB=GaussianNB()   #when the features have continuous values.
GNB.fit(train_input_SMOTE,train_output_SMOTE)
pred_GNB=GNB.predict(test_input)
GNB_acc = accuracy_score(test_output,pred_GNB)*100
print("accuracy of GNB :", round(GNB_acc,2),"%")
# Out:
# accuracy of GNB : 65.37 %

# %%
#Plot confusion matrix for Gaussian Naives Bayes

confusion_matrix_gb = confusion_matrix(test_output, pred_GNB.round())
print("Confusion Matrix - Gaussian Naives Bayes")
print(confusion_matrix_gb)
# Out:
# Confusion Matrix - Gaussian Naives Bayes
# [[5821 3741]
#  [ 463 2116]]

# %%
#Display the visualization of the Confusion Matrix.
import seaborn as sns

ax = sns.heatmap(confusion_matrix_gb/np.sum(confusion_matrix_gb), annot=True, 
            fmt='.2%', cmap='RdBu_r')
ax.set_title('Seaborn Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

plt.show()

# %% [markdown]
# ###### This confusion matrix by Gaussian Naive Bayes shows that the proportion of  correctly predicted no-event values(TN), incorrectly predicted event values(FP), incorrectly predicted no-event values (FN), correctly predicted event values(TP Values) are 47.84%,30.81%,3.81% and 17.43% respectively .

# %%
from sklearn.metrics import classification_report
print(classification_report(test_output, pred_GNB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.61      0.73      9562
#            1       0.36      0.82      0.50      2579
#
#     accuracy                           0.65     12141
#    macro avg       0.64      0.71      0.62     12141
# weighted avg       0.81      0.65      0.69     12141

# %%
# Comparing Accuracies

labels =["Logistic Regression","KNN", "Random Forest" , "Naive Bayes" ]
x = [ logistic_acc,knn_acc,RFC_acc,GNB_acc]
eval_frame=pd.DataFrame()
eval_frame['Model']=labels
eval_frame['Train_test_split'] = x
eval_frame
# Out:
#                  Model  Train_test_split
# 0  Logistic Regression         73.198254
# 1                  KNN         74.516102
# 2        Random Forest         81.805453
# 3          Naive Bayes         65.373528

# %% [markdown]
# # K Fold Cross Validation

# %%
#Because it ensures that every observation from the original dataset has the chance of appearing in training and test set.
#Cross validation (CV) is one of the technique used to test the effectiveness of a machine learning models, 
#it is also a re-sampling procedure used to evaluate a model if we have a limited data. To perform CV we need to keep aside a 
#sample/portion of the data on which is not used to train the model, later use this sample for testing/validating.
 
#it generally results in a less biased model compare to other methods. Because it ensures that every observation from the
#original dataset has the chance of appearing in training and test set. This is one among the best approach if we have a 
#limited input data. 

from sklearn.model_selection import KFold
kfold = KFold(n_splits=5)   #Split the entire data randomly into K folds value should be between 5 to 10

# %%
# Modeling step Test differents algorithm
classifiers1 = []     #to recognize objects and being able to separate them into categories.
#it helps us segregate vast 
                       #quantities of data into discrete values,

# %%
# ? extracts models describing data classes
# A classification model reads some input and generates an output that classifies the input into 
#some category.
classifiers1.append(KNeighborsClassifier())   #the KNeighborsClassifier looks for the 5 nearest neighbors.
classifiers1.append(LogisticRegression())
classifiers1.append(GaussianNB())  #helps in building the fast machine learning models that can make quick predictions.
classifiers1.append(RandomForestClassifier())# It provides higher accuracy through cross validation. 
#Random forest classifier will handle the missing values and maintain the accuracy of a large 
#proportion of data.

# %%
from sklearn.model_selection import cross_val_score

# %%
accuracy_results1 = []
for a in classifiers1:
    accuracy_results1.append(cross_val_score(a, train_input_SMOTE, train_output_SMOTE, scoring= "accuracy", cv=kfold))

# %%
accuracy_results1
# Out:
# [array([0.74204788, 0.74429583, 0.7399955 , 0.8817446 , 0.88938849]),
#  array([0.6930426 , 0.69956165, 0.70065198, 0.65714928, 0.59296313]),
#  array([0.63954142, 0.64516129, 0.63657824, 0.82790018, 0.85802608]),
#  array([0.8420816 , 0.83679892, 0.83655576, 0.92535971, 0.93603867])]

# %%
accuracy_means1 = []
for e in accuracy_results1:
    accuracy_means1.append(e.mean()*100)

# %%
accuracy_means1
# Out:
# [79.94944616971365, 66.86737274224679, 72.14414410362235, 87.53669316429514]

# %%
eval_frame['kfold_5']=accuracy_means1
eval_frame
# Out:
#                  Model  Train_test_split    kfold_5
# 0  Logistic Regression         73.198254  79.949446
# 1                  KNN         74.516102  66.867373
# 2        Random Forest         81.805453  72.144144
# 3          Naive Bayes         65.373528  87.536693

# %% [markdown]
# # Stratifiedkfold_5

# %% [markdown]
# #### Stratified K-Folds cross-validator.It provides train/test indices to split data in train/test sets.This cross-validation object is a variation of KFold that returns stratified folds. The folds are made by preserving the percentage of samples for each class

# %%
from sklearn.model_selection import StratifiedKFold
Stratifiedkfold = StratifiedKFold(n_splits=5)
# Modeling step Test differents algorithm
classifiers_4 = []
classifiers_4.append(KNeighborsClassifier())
classifiers_4.append(LogisticRegression())
classifiers_4.append(GaussianNB())
classifiers_4.append(RandomForestClassifier())

accuracy_results_4 = []
for a in classifiers_4:
    accuracy_results_4.append(cross_val_score(a, train_input_SMOTE, train_output_SMOTE, scoring= "accuracy", cv=Stratifiedkfold))
accuracy_means_4 = []
for e in accuracy_results_4:
    accuracy_means_4.append(e.mean()*100)
accuracy_means_4
eval_frame['Stratifiedkfold_5']=accuracy_means_4

eval_frame
# Out:
#                  Model  Train_test_split    kfold_5  Stratifiedkfold_5
# 0  Logistic Regression         73.198254  79.949446          82.784099
# 1                  KNN         74.516102  66.867373          73.980514
# 2        Random Forest         81.805453  72.144144          73.818666
# 3          Naive Bayes         65.373528  87.536693          88.359547
